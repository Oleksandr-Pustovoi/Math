# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
k = 2

x = np.linspace(-np.pi*2, np.pi*2, 201)
plt.plot(x, np.cos(x))
plt.plot(x, np.cos(x*k))
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()
